# %% [markdown]
# # Import Packages

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Load Data

# %% [markdown]
# # 1. User info. (no age)

# %%
final_v2 = pd.read_csv("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/final_v2.csv")
test_v27_json = pd.read_json("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v27.json")
test_v28_json = pd.read_json("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v28.json")
test_v29_json = pd.read_json("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v29.json")
test_v30_json = pd.read_json("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v30.json")
test_v31_json = pd.read_json("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v31.json")

# %% [markdown]
# ## 1.1 combine data

# %%
combined_data_list_1 = [final_v2, test_v27_json, test_v28_json, test_v29_json, test_v30_json, test_v31_json]
combined_data_1 = pd.concat(combined_data_list_1)

# %%
combined_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2245 entries, 0 to 3
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   section_name         2245 non-null   object
#  1   thread_title         2245 non-null   object
#  2   post_ID              2245 non-null   object
#  3   post_date            2245 non-null   object
#  4   post_username        2245 non-null   object
#  5   post_text            2125 non-null   object
#  6   post_order           2245 non-null   object
#  7   replier_post_ID      360 non-null    object
#  8   user_location        782 non-null    object
#  9   user_gender          584 non-null    object
#  10  user_occupation      283 non-null    object
#  11  user_messages_count  2245 non-null   object
#  12  user_reaction_score  2245 non-null   object
#  13  user_mygarage        384 non-null    object
# dtypes: object(14)
# memory usage: 263.1+ KB

# %% [markdown]
# ## 1.2 data pre-processing

# %%
# rename column
combined_data_1.rename(columns={"user_mygarage": "user_car"}, inplace = True)

# %%
# fill missing values with "NA"
combined_data_1 = combined_data_1.fillna("NA")

# %%
# convert to string
combined_data_1 = combined_data_1.applymap(str)

# %%
# replace "NA" of NaN to check none values
combined_data_1 = combined_data_1.replace('NA', np.NaN)

# %%
# check data type in each row
# print(combined_data_1.applymap(type))

# %%
combined_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2245 entries, 0 to 3
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   section_name         2245 non-null   object
#  1   thread_title         2245 non-null   object
#  2   post_ID              2245 non-null   object
#  3   post_date            2245 non-null   object
#  4   post_username        2245 non-null   object
#  5   post_text            2125 non-null   object
#  6   post_order           2245 non-null   object
#  7   replier_post_ID      360 non-null    object
#  8   user_location        766 non-null    object
#  9   user_gender          567 non-null    object
#  10  user_occupation      251 non-null    object
#  11  user_messages_count  2245 non-null   object
#  12  user_reaction_score  2245 non-null   object
#  13  user_car             384 non-null    object
# dtypes: object(14)
# memory usage: 263.1+ KB

# %% [markdown]
# # 2. User info (no car info)

# %%
test_v20 = pd.read_csv("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v20.csv")
test_v19_json = pd.read_json("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v19.json")
test_v20_json= pd.read_json("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v20.json")

# %% [markdown]
# ## 2.1 combine data

# %%
combined_data_list_2 = [test_v20, test_v19_json, test_v20_json]
combined_data_2 = pd.concat(combined_data_list_2)

# %% [markdown]
# ## 2.2 data pre-processing

# %%
combined_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 908 entries, 0 to 24
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   section_name         908 non-null    object
#  1   thread_title         908 non-null    object
#  2   post_ID              908 non-null    object
#  3   post_date            908 non-null    object
#  4   post_username        908 non-null    object
#  5   post_text            904 non-null    object
#  6   post_order           908 non-null    object
#  7   replier_post_ID      868 non-null    object
#  8   user_location        886 non-null    object
#  9   user_gender          886 non-null    object
#  10  user_occupation      868 non-null    object
#  11  user_messages_count  908 non-null    object
#  12  user_reaction_score  908 non-null    object
# dtypes: object(13)
# memory usage: 99.3+ KB

# %%
# fill missing values with "NA"
combined_data_2 = combined_data_2.fillna("NA")

# %%
# convert to string
combined_data_2 = combined_data_2.applymap(str)

# %%
# replace "NA" of NaN to check none values
combined_data_2 = combined_data_2.replace('NA', np.NaN)

# %%
# check data type in each row
# print(combined_data_1.applymap(type))

# %%
combined_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 908 entries, 0 to 24
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   section_name         908 non-null    object
#  1   thread_title         908 non-null    object
#  2   post_ID              908 non-null    object
#  3   post_date            908 non-null    object
#  4   post_username        908 non-null    object
#  5   post_text            904 non-null    object
#  6   post_order           908 non-null    object
#  7   replier_post_ID      868 non-null    object
#  8   user_location        426 non-null    object
#  9   user_gender          308 non-null    object
#  10  user_occupation      156 non-null    object
#  11  user_messages_count  908 non-null    object
#  12  user_reaction_score  908 non-null    object
# dtypes: object(13)
# memory usage: 99.3+ KB

# %% [markdown]
# # 3. User info. (full)

# %%
test_v32_json= pd.read_json("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v32.json")
real_final_v1 = pd.read_csv("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/real_final_v1.csv")
real_final_v2 = pd.read_csv("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/real_final_v2.csv")
real_final_v3 = pd.read_csv("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/real_final_v3.csv")
real_final_v4 = pd.read_csv("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/real_final_v4.csv")
real_final_v5 = pd.read_csv("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/real_final_v5.csv")
maserati_v1 = pd.read_csv("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/maserati_v1.csv")
maserati_v2 = pd.read_csv("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/maserati_v2.csv")

# %%
maserati_v1["section_name"] = maserati_v1["section_name"].str.replace("Global", "Maserati")
maserati_v2["section_name"] = maserati_v2["section_name"].str.replace("Global", "Maserati")

# %% [markdown]
# ## 3.1 combine data

# %%
combined_data_list_3 = [test_v32_json, real_final_v1, real_final_v3, real_final_v4, real_final_v5, maserati_v1, maserati_v2]
combined_data_3 = pd.concat(combined_data_list_3)

# %% [markdown]
# ## 3.2 data pre-processing

# %%
combined_data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 985 entries, 0 to 219
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   section_name         985 non-null    object
#  1   thread_title         985 non-null    object
#  2   post_ID              985 non-null    object
#  3   post_date            985 non-null    object
#  4   post_username        985 non-null    object
#  5   post_text            930 non-null    object
#  6   post_order           985 non-null    object
#  7   replier_post_ID      112 non-null    object
#  8   user_birthday        378 non-null    object
#  9   user_location        612 non-null    object
#  10  user_gender          323 non-null    object
#  11  user_occupation      289 non-null    object
#  12  user_messages_count  985 non-null    object
#  13  user_reaction_score  985 non-null    object
#  14  user_car             394 non-null    object
# ...

# %%
# fill missing values with "NA"
combined_data_3 = combined_data_3.fillna("NA")

# %%
# convert to string
combined_data_3 = combined_data_3.applymap(str)

# %%
# replace "NA" of NaN to check none values
combined_data_3 = combined_data_3.replace('NA', np.NaN)

# %% [markdown]
# # 4. Post text (no user info)

# %%
test_v12_json = pd.read_json('/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v12.json')
test_v13_json = pd.read_json("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v13.json")
test_v25_json = pd.read_json("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v25.json")
test_v26_json = pd.read_json("/Users/irene/CloudStation/Courses/ARP/ARP code/Maserati-ARP/Maserati-ARP/Forums-data-collection/germancarforum/germancarforum_/germancarforum_/spiders/test_v26.json")

# %% [markdown]
# ## 4.1 combine data

# %%
combined_data_list_4 = [test_v12_json, test_v13_json, test_v25_json, test_v26_json]
combined_data_4 = pd.concat(combined_data_list_4)

# %%
combined_data_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 196966 entries, 0 to 481
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   section_name     196966 non-null  object
#  1   thread_title     196966 non-null  object
#  2   post_ID          196966 non-null  object
#  3   post_date        196966 non-null  object
#  4   post_username    192708 non-null  object
#  5   post_text        196966 non-null  object
#  6   post_order       196966 non-null  object
#  7   replier_post_ID  196966 non-null  object
# dtypes: object(8)
# memory usage: 13.5+ MB

# %% [markdown]
# ## 4.2 data pre-processing

# %%
# fill missing values with "NA"
combined_data_4 = combined_data_4.fillna("NA")

# %%
# convert to string
combined_data_4 = combined_data_4.applymap(str)

# %%
# replace "NA" of NaN to check none values
combined_data_4 = combined_data_4.replace('NA', np.NaN)

# %% [markdown]
# # Combine All Data Together

# %% [markdown]
# ## 1. Merge all data

# %%
user_data_not_full = combined_data_1.merge(combined_data_2, how = "outer")

# %%
user_data_full = user_data_not_full.merge(combined_data_3, how = "outer")

# %%
final = user_data_full.merge(combined_data_4, how = "outer")

# %% [markdown]
# ## 1.2 NLP data

# %% [markdown]
# ### Data pre-processing

# %%
# convert to integer
final["user_messages_count"] = final["user_messages_count"].str.replace(",", "")
final["user_messages_count"] = pd.to_numeric(final["user_messages_count"])

final["user_reaction_score"] = final["user_reaction_score"].str.replace(",", "")
final["user_reaction_score"] = pd.to_numeric(final["user_reaction_score"])

# %%
# post_order
final["post_order"] = final["post_order"].str.replace("#", "")
final["post_order"] = final["post_order"].str.replace(",", "")
final["post_order"] = pd.to_numeric(final["post_order"])

# %%
# remove post-
final["post_ID"] = final["post_ID"].str.replace("post-", "")

# replace \n\t
final["user_birthday"] = final["user_birthday"].str.replace("\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t", " ")

# %%
# drop duplicates but keep last in post_ID
final  = final.drop_duplicates(subset=['post_ID'], keep='last')

# %%
# remove nonsense data in user_location
final['user_location'] = final['user_location'].replace({
    'cast away': '',
    'Earth': '',
    'egerton': '',
    'Far Far Away': '',
    'Here today, hell tomorrow': '',
    'In my Empire.': '',
    'in the lambo factory': '',
    'in the middle': '',
    'L': '',
    'Middle of Nowhere': '',
    'Montreal,  worst roads in NA!!!': '',
    'north hollywood': '',
    "Not there where I'd like to": '',
    'Right Here': '',
    'somewhere': '',
    'The D': '',
    'The Malebolge': '',
    'Unknown': '',
    'virgo supercluster': '',
    'Where climate means 4MATIC is necessary': '',
    'Worldwide; traveler': ''
})

# %%
# map user_location to user_country
country = {
', , NL':'USA',
'101 Great North Road, Grey Lynn 1021, New Zealand':'USA',
'33301':'USA', 
'400001':'India', 
'Abu Dhabi, United Arab Emirates':'UAE', 
'Abu Dhabi,UAE':'UAE', 
'Adelaide':'Australia', 
'Ala-Tenn':'USA', 
'Alberta Canada':'Canada', 
'Alpharetta, Georgia, US': 'USA', 
'Ampthill, Bedfordshire, England': 'UK', 
'Ankara': 'Turkey', 
'Ann Arbor, MI, USA': 'USA', 
'Annecy, France': 'France', 
'Arcadia, California': 'USA', 
'Arlington,Texas': 'USA',
'Asia': 'Taiwan',
'Athens': 'Greece',
"Athens Greece": "Greece",
'Athens, Attica, GR': 'Greece', 
'Athens, Greece': 'Greece', 
'Atlanta':'USA', 
'Atlanta GA. USA':'USA', 
'Atlanta, GA':'USA', 
'Auckland New Zealand': 'New Zealand', 
'Austin, TX': 'USA', 
'Austin, TX, USA': 'USA', 
'Australia': 'Australia',
'Australia, Melbourne': 'Australia', 
'Austria': 'Austria', 
'BAYERN': 'Germany', 
'BELL CALIFORNIA': 'USA', 
'Bahrain': 'Bahrain', 
'Baku, Azerbaijan, Azerbaijan': 'Azerbaijan',
'Baku,AZERBAIJAN': 'Azerbaijan', 
'Bamberg, Germany': 'Germany', 
'Bangkok': 'Thailand',
'Bangkok, Thailand': 'Thailand', 
'Banska Bystrica, Slovakia': 'Slovakia', 
'Bay Area, CA': 'USA',
'Belgium' : 'Belgium',
'Belgium, GENK': 'Belgium', 
'Belgrade, , RS': 'Serbia', 
'Belgrade, Serbia': 'Serbia', 
'Bell California': 'USA',
'Bell California , USA':'USA',
'Berlin': 'Germany',
'Berlin, Germany': 'Germany', 
'Bethlehem, Pennsylvania, US': 'USA',
'Bilbo (Basque Country)': 'Spain', 
'Birmingham, Alabama': 'USA', 
'Boca Raton, FL': 'USA', 
'Boca Raton, FL . Rotterdam, NL . Iceland': 'Netherlands', 
'Bologna, Italy': 'Italy', 
'Bornum am Elm': 'Germany', 
'Bosnia &amp; Herzegovina-Republic of Srpska': 'Bosnia and Herzegovina', 
'Bosnia and Herzegovina': 'Bosnia and Herzegovina',
'Boynton Beach, FL, United States': 'USA',
'Brazil': 'Brazil', 
'Brighton, England': 'UK', 
'Brisbane, Australia': 'Australia', 
'Britain': 'UK', 
'Brookside': 'UK', 
'Bruchsal, Deutschland': 'Germany', 
'Bucharest': 'Romania',
'Bucharest, ROMANIA': 'Romania',
'Bucharest, Romania': 'Romania', 
'Buenos Aires': 'Argentina', 
'Bulgaria': 'Bulgaria', 
'Bursa - Turkey': 'Turkey', 
'CA': 'USA', 
'CAIRO-EGYPT': 'Egypt', 
'CAMDEN. Arkansas, USA': 'USA', 
'Cairo.': 'Egypt', 
'Calgary, Alberta': 'Canada', 
'Calicut, Kerala, India': 'India', 
'California': 'USA', 
'California, USA': 'USA', 
'California, United States': 'USA', 
'Cambridge': 'UK', 
'Cambridgeshire, England': 'UK', 
'Canada': 'Canada', 
'Cape Town, South Africa': 'South Africa', 
'Cardiff': 'UK', 
'Carmel-by-the-Sea, CA': 'USA', 
'Central District, , HK': 'Hong Kong', 
'Central Scotland': 'UK', 
'Charlotte, NC': 'USA', 
'Charlottesville, VA': 'USA', 
'Cheltenham': 'UK', 
'Chester': 'UK', 
'Chicago, IL': 'USA',
'China': 'China', 
'Cincinnati': 'USA', 
'Coimbra, Portugal': 'Portugal', 
'Colorado': 'USA', 
'Colorado, USA': 'USA', 
'Connecticut/New York': 'USA', 
'Croatia': 'Croatia', 
'Cyprus': 'Cyprus', 
'Czech': 'Czech Republic', 
'DC': 'USA', 
'DFW': 'USA', 
'DK': 'Denmark', 
'Dammam, Saudi Arabia': 'Saudi Arabia',
'Daytona Beach, FL, USA': 'USA', 
'Delano, MN': 'USA', 
'Delray Beach, FL': 'USA',
####
"Denmark": "Denmark", 
"Denver, Colorado": "USA", 
"Derby": "UK", 
"Detroit, MI": "USA", 
"Detroit, MI, United States": "USA", 
"Discovery Bay": "China", 
"DisneyWorld  Florida": "USA", 
"Doha": "Qatar", "Dubai": "UAE", 
"Dubai, UAE": "UAE",
"Dubuque, Iowa, United States": "USA", 
"Dundee, Scotland, UK": "UK", 
"Earth": "", 
"East Coast": "USA", 
"Edmonton, Canada": "Canada", 
"England": "UK", 
"England, UK": "UK", 
"Europe": "UK", "FRANCE": "France", 
"Far Far Away": "", 
"Finland": "Finland", 
"Firenze, Italy": "Italy", 
"Florida City, FL, USA": "USA", 
"Florida US": "USA", 
"Florida and Connecticut, USA": "USA", 
"Florida by the water": "USA", 
"Florida, USA": "USA", 
"France": "France", 
"Frankfurt am Main, Hesse, DE": "Germany", 
"Frankfurt, Germany": "Germany", 
"Fregate, La Digue, Seychelles": "Seychelles", 
"Frisco, TX, USA": "USA", 
"Gatineau Québec Canada": "Canada", 
"Geneva,Switzerland": "Switzerland", 
"Germany": "Germany", 
"Germany - Stuttgart": "Germany", 
"Germany, Bavaria": "Germany", 
"Germany, Bavaria, Wzbg.": "Germany", 
"Great Plains": "USA", 
"Greece": "Greece", 
"Greece Athens": "Greece", 
"Greenville, SC": "USA", 
"Greenville,SC": "USA", 
"Györ/Hungary": "Hungary", 
"HELSINKI FINLAND": "Finland", 
"Halesowen": "UK", 
"Halifax, Nova Scotia": "Canada", 
"Hamme, Belgium": "Belgium", 
"Hannover": "Germany",
"Hanoi, Vietnam": "Vietnam",
"Hanover": "Germany",
"Hanover, PA": "Germany",
"Helsinki, Finland": "Finland",
"Helvetia": "Switzerland",
"Here today, hell tomorrow": "",
"High Point, NC, USA": "USA",
"Hilton,NY": "USA",
"Holland, Den Haag.": "Netherlands",
"Hong Kong": "Hong Kong",
"Houston": "USA",
"Houston & Calgary": "USA",
"Houston, Texas": "USA",
"Houston, Texas, United States": "USA",
"Hungary": "Hungary",
"Hunstanton, Norfolk, England": "UK",
"Hà Nội, Hoàn Kiếm, Hanoi, Vietnam": "Vietnam",
"IA": "USA", "IN &amp; NC": "USA",
"Iceland": "Iceland",
"Idaho": "USA", "Illinois": "USA",
"In my Empire.": "",
"India": "India",
"Indiana, USA": "USA",
"Indonesia, Jakarta, Kemang": "Indonesia",
"Iran": "Iran",
"Israel": "Israel",
"Istanbul (Turkey) and Exeter (UK)": "Turkey",
"Istanbul, Turkey": "Turkey",
"Italia": "Italy",
"Italia>Venezia>Modena": "Italy",
"Italy": "Italy",
"Jacksonville FL": "USA",
"Jakarta, Indonesia": "Indonesia",
"Jamaica -&gt; US -&gt; Germany": "Jamaica",
"Johannesburg": "South Africa",
"Johannesburg SA": "South Africa",
"Johannesburg, Gauteng, ZA": "South Africa",
"Johannesburg, S.A.": "South Africa",
"Johannesburg, South Africa": "South Africa",
"KSA": "Saudi Arabia", "Kansas": "USA",
"Knoxville, Tennessee": "USA",
"Korea": "Korea",
"Kozhikode, Kerala, IN": "India",
"Kuwait": "Kuwait",
"Kyiv": "Ukraine",
"L": "",
"L.A.": "USA",
"La Jolla": "USA",
"Lahti, Päijänne Tavastia, FI": "Finland",
"Landover, Maryland": "USA",
"Langreo, Spain": "Spain",
"Las Vegas": "USA",
"Las Vegas, NV  USA": "USA",
"Latvia": "Latvia",
"Lillehammer, Norway": "Norway",
"Lithuania": "Lithuania",
####
"London": "UK",
"London &amp; Vilnius (Lithuania)": "UK",
"London, England, GB": "UK",
"London, Ont.": "UK",
"London, UK": "UK",
"London/Singapore": "UK",
"Long Island, New York, USA": "USA",
"Longmont, CO": "USA",
"Los Angeles": "USA",
"Los Angeles County, California": "USA",
"Los Angeles, CA": "USA",
"Los Angeles, CA, United States": "USA",
"Los Angeles, Ca": "USA",
"Los Angeles, California": "USA",
"Los Angeles, California, US": "USA",
"Los Angeles, California, USA": "USA",
"Luxemburg": "Luxemburg",
"Madrid": "Spain",
"Madrid, Spain": "Spain",
"Madrid/Brussels": "Spain",
"Mainland China, and Hong Kong on weekends.": "Hong Kong",
"Mainz, Germany": "Germany",
"Malacca, Malaysia": "Malaysia",
"Malaysia": "Malaysia",
"Malaysia, KL": "Malaysia",
"Manchester, UK": "UK",
"Manhattan.": "USA",
"Maryland, USA": "USA",
"Mass": "USA",
"Mediterranean Sea": "Cyprus",
"Melborne": "Australia",
"Melbourne, Australia": "Australia",
"Melbourne, Vic, Australia": "Australia",
"Memphis, TN": "USA",
"Mercedes-Benz World": "Germany",
"Mercer Island, WA, USA": "USA",
"Merica": "USA",
"Merseyside, UK": "UK",
"Mexico City": "Mexico",
"Miami": "USA",
"Miami, FL": "USA",
"Miami, Fl.": "USA",
"Middle of Nowhere": "",
"Minnesota (U.S.A)": "USA",
"Minsk, Belarus": "Belarus",
"Monaco": "Monaco",
"Montreal": "Canada",
"Montreal, worst roads in NA!!!": "Canada",
"Montreal, Canada": "Canada",
"Monza": "Italy",
"Morocco": "Morocco",
"Moscow.": "Russia",
"Moval U.S.A": "USA",
"Mumbai, India": "India",
"Mumbai, Maharashtra, India": "India",
"Munich": "Germany",
"Munich and Los Angeles": "Germany",
"Munich, Bavaria": "Germany",
"Munich, Germany": "Germany",
"Málaga, Spain": "Spain",
"México": "Mexico",
"München, Germany": "Germany",
"NC USA/SW Finland": "Finland",
"NC-USA": "USA",
"NE": "USA",
"NJ, USA": "USA",
"NJ/TX": "USA",
"NO": "USA",
"NOLA": "USA",
"NORCAL": "USA",
"NORWICH, CT": "USA",
"NOVA - USA": "USA",
"NSW, Australia.": "Australia",
"NY": "USA",
"NYC": "USA",
"NYork": "USA",
"Nairobi.": "Kenya",
"Naples, Florida": "USA",
"Narnia": "UK",
"Nashville, TN, USA": "USA",
"Nelson UK": "UK",
"Neringa, Lithunia": "Lithuania",
"Netherlands": "Netherlands",
"New Jersey": "USA",
"New Jersey, USA": "USA",
"New York": "USA",
"New York City": "USA",
"New York, NY, United States": "USA",
"Newport Beach, Ca, USA...": "USA",
"Newyork": "USA",
"Nivelles, Belgium": "Belgium",
"Nj": "USA",
"North Wales uk": "UK",
"Northvale, NJ": "USA",
"Norway": "Norway",
"Not there where I'd like to": "",
"O.C.": "USA",
"Ohio, USA": "USA",
"Orange County, CA": "USA",
"Orange County, California Area, USA": "USA",
"Oregon, United States": "USA",
"Orlando": "USA",
"Oslo, Norway": "Norway",
"Ottawa, Canada": "Canada",
"Ottawa, Ontario": "Canada",
"Oulu, Finland": "Finland",
"P.R.China/Toronto Canada": "Canada",
"PT": "USA",
####
"Palm Beach,Fl": "USA", 
"Panama City, Panama": "Panama", 
"Papenburg...": "Germany", 
"Paris": "France", 
"Patras, Greece": "Greece", 
"Pembrokeshire, UK": "UK", 
"Perth": "Australia", 
"Perth, Australia": "Australia",
"Perth, Scotland": "UK", 
"Philadelphia, Pennsylvania": "USA", 
"Philippines": "Philippines", 
"Phoenix Arizona": "USA", 
"Pittsburgh,PA, USA": "USA", 
"Poconos, PA": "USA", 
"Poland": "Poland", 
"Portland, Oregon": "USA", 
"Portugal": "Portugal", 
"Prague": "Czech Republic", 
"Puerto Rico": "Puerto Rico", 
"Qatar": "Qatar", 
"Queens NY": "USA", 
"Rastatt, Germany": "Germany", 
"Reno, NV": "USA", 
"Republic of South-Africa": "South Africa", 
"Rhode island, USA": "USA", 
"Riga": "Latvia", 
"Right Here": "", 
"Rio de Janeiro, Brazil": "Brazil",
"Riyadh-Dubai": "UAE",
"Rocklin Ca": "USA",
"Romania": "Romania", 
"Rome (It)": "Italy", 
"Russia": "Russia", 
"Russia, Saint-Petersburg": "Russia", 
"S.Florida": "USA", 
"SA": "South Africa", 
"SARASOTA, FLORIDA": "USA", 
"SF": "USA", 
"SF Bay Area": "USA", 
"SIbiu": "Romania", 
"SPAIN": "Spain", 
"SW USA": "USA",
"Salinas": "Spain", 
"San Carlos, CA": "USA", 
"San Diego, CA, United States": "USA", 
"San Francisco": "USA", 
"San Francisco Bay Area/Nottingham, England": "USA", 
"San Francisco, CA": "USA", 
"San Francisco, CA / Woodbury,CT": "USA", 
"San Francisco, California": "USA", 
"San Jose ,CA": "USA", 
"San Jose, California (Aussie expat)": "USA", 
"San Leandro, California, United States": "USA", 
"San NicolÃ¡s De Los Garzas, Nuevo Leon, Mexico, Me": "Mexico", 
"Sandton, South Africa": "South Africa", 
"Santa Cruz,ca": "USA",
"Santa Margarita California": "USA", 
"Santa Monica, CA USA": "USA", 
"Santiago, Cl &amp; Boulder, CO": "Spain", 
"Sarajevo, Bosnia and Herzegovina, Bosnia and Herze": "Bosnia and Herzegovina", 
"Sarasota": "USA", 
"Saudi Arabia and South Africa": "South Africa", 
"Scania": "Sweden", 
"Scotland": "UK", 
"Scottsdale Arizona": "USA", 
"Seattle, Washington USA": "USA",
"Seattle,WA": "USA", 
"Sebastopol, California": "USA", 
"Serbia": "Serbia", 
"Siberia": "Russia",
"Singapore": "Singapore",
"Skopje, Macedonia": "North Macedonia", 
"Slovak Republic": "Slovakia", 
"Slovenia": "Slovenia", 
"Slovenia, EU": "Slovenia", 
"Slovenia, Ljubljana": "Slovenia", 
"Soerabaia": "USA", 
"South Africa": "South Africa", 
"South Florida": "USA", 
"South africa": "South Africa", 
"Southampton, UK": "UK", 
"Southern California, USA": "USA", 
"Spain": "Spain", 
"St. Louis, Missouri": "USA", 
"State of Maine, USA": "USA", 
"Stockholm": "Sweden", 
"Stockholm - Sweden": "Sweden", 
"Stockholm, Stockholm, SE": "Sweden", 
"Stockholm, Sweden": "Sweden", 
"Stratham, NH": "USA", 
"Stuttgart": "Germany", 
"Stuttgart, Germany": "Germany", 
"Sugar Grove, IL": "USA", 
"Sunny South Africa": "South Africa", 
"Surrey": "UK", 
"Swampyland, UK": "UK", 
"Sweden": "Sweden", 
"Sweden, Norrköping": "Sweden", 
"Sweden, and sometimes Germany": "Sweden",
"Switzerland": "Switzerland",
"Switzerland :-)": "Switzerland", 
"Sydney": "Australia", 
"Sydney Australia": "Australia", 
"Sydney (most of the time)": "Australia", 
"Sydney Australia": "Australia", 
"Sydney NSW, Australia": "Australia", 
"Sydney, Australia": "Australia",
#####
'Sydney, NSW, Australia': 'Australia',
'Sydney,Australia': 'Australia',
'Syria': 'Syria',
'São Paulo, Sao Paulo, BR':'Brazil',
'TX':'USA',
'Tamp/Boston/who knows':'USA',
'Tampa, FL':'USA', 
'Tel Aviv, Israel': 'Israel',
'Tempe': 'USA',
'Tennessee, USA': 'USA',
'Texas':'USA',
'The D':'',
'The Hague, The Netherlands':'Netherlands',
'The Malebolge': '',
'The Netherlands': 'Netherlands',
'The Sunny Beaches of Florida':'USA',
'Thorpe Waterville': 'UK',
'Thunder Bay, Ontario':'Canada',
'Tilburg': 'Netherlands',
'Toorak, Victoria, AU': 'Australia',
'Toronto':'Canada',
'Toronto, Canada':'Canada',
'Turkey':'Turkey',
'Tustin, Ca':'USA',
'U.S.A':'USA',
'U.S.A.':'USA',    
'UAE':'UAE',    
'UK':'UK',
'US':'USA',    
'USA':'USA',
'USA-NJ':'USA',
'United Arab Emirates':'UAE',
'United Arab Emirates - Switzerland':'Switzerland',
'United Kingdom':'UK',
'United States': 'USA',
'United States of America': 'USA',
'Unknown':'',
'Utah': 'USA',
'VA-USA':'USA',
'Valencia (España/Spain)': 'Spain',    
'Vancouver':'Canada',
'Vancouver BC':'Canada',
'Vancouver, B.C': 'Canada',
'Vancouver, BC': 'Canada',
'Veneto, Italy': 'Italy',
'Vermont':'USA',
'Victoria': 'Australia',
'Vienna, Austria': 'Austria',
'Vietnam':'Vietnam',
'Vila Nova, Porto, PT':'Portugal',
'WV':'USA',
'Warsaw':'Poland',
'Warszawa, Poland':'Poland',
'Washington, DC':'USA',
'Washington, District of Columbia, United States':'USA',
'Western Canada':'Canada',
'Where climate means 4MATIC is necessary':'',
'Wisconsin':'USA',
'Wokingham, England':'UK',
'Worcester, MA':'USA',
'Worldwide; traveler':'',
'Zagreb':'Croatia',
'Zurich': 'Switzerland',
'adlington ENGLAND':'UK',
'amsterdam':'Netherlands',
'berlin': 'Germany',
'cape town, south africa':'South Africa',
'cast away':'',
'champaign, IL':'USA',
'egerton':'',
'france':'France',
'germany': 'Germany',
'in the lambo factory':'',
'in the middle':'',
'istanbul':'Turkey',
'istanbul_Turkiye':'Turkey',
'jordan':'UAE',
'kuwait':'Kuwait',
'london':'UK',
'london, England, GB':'UK',
'michigan':'USA',
'near Zurich, Switzerland':'Switzerland',
'noVA, USA':'USA',
'north hollywood':'',
'norway':'Norway',
'qingdao,china':'China',
'skopje':'North Macedonia',
'somewhere':'',
'south africa':'South Africa',
'south america':'USA',
'sweden':'Sweden',
'tennessee':'USA',
'the Netherlands':'Netherlands',
'torino - italy':'Italy',
'trinidad': 'Trinidad and Tobago',
'turkey': 'Turkey',
'ukraine':'Ukraine',
'united kingdom':'UK',
'usa':'USA',
'virgo supercluster':'',
'west coast':'USA',
'Épinal, France':'France',
'Краснодар, Россия':'Russia',
"成都": "China",
####
"Pittsburgh, PA, USA": "USA",
"Sydney    Australia": "Australia",
"Vancouver, B.C.": "Canada",
"Zagreb, City of Zagreb, HR": "Croatia",
"Zagreb,Croatia": "Croatia"
}

final['user_country'] = final['user_location'].map(country)

# %%
# map user_country to user_continent
continent = {
"USA": "North America",
"UK": "Europe",
"Australia": "Oceania",
"Germany": "Europe",
"Canada": "North America",
"South Africa": "Africa",
"Sweden": "Europe",
"Greece": "Europe",
"France": "Europe",
"Netherlands": "Europe",
"Croatia": "Europe",
"Norway": "Europe",
"Finland": "Europe",
"Spain": "Europe",
"UAE": "Asia",
"Italy": "Europe",
"Belgium": "Europe",
"India": "Asia",
"Poland": "Europe",
"Turkey": "Asia",
"Russia": "Europe",
"Brazil": "South America",
"Switzerland": "Europe",
"Romania": "Europe",
"Serbia": "Europe",
"Malaysia": "Asia",
"Austria": "Europe",
"Portugal": "Europe",
"Hong Kong": "Asia",
"Egypt": "Africa",
"Qatar": "Asia",
"Mexico": "North America",
"Israel": "Asia",
"China": "Asia",
"Kuwait": "Asia",
"Bosnia and Herzegovina": "Europe",
"Bulgaria": "Europe",
"Singapore": "Asia",
"Kenya": "Africa",
"Saudi Arabia": "Asia",
"Denmark": "Europe",
"Cyprus": "Europe",
"Luxemburg": "Europe",
"Lithuania": "Europe",
"Slovenia": "Europe",
"Seychelles": "Africa",
"Vietnam": "Asia",
"Iran": "Asia",
"Czech Republic": "Europe",
"North Macedonia": "Europe",
"Azerbaijan": "Asia",
"Monaco": "Europe",
"Taiwan": "Asia",
"Hungary": "Europe",
"Latvia": "Europe",
"Slovakia": "Europe",
"Thailand": "Asia",
"Syria": "Asia",
"Ukraine": "Europe",
"Indonesia": "Asia",
"Morocco": "Africa",
"Panama": "North America",
"Argentina": "South America",
"Philippines": "Asia",
"New Zealand": "Oceania",
"Korea": "Asia",
"Puerto Rico": "North America",
"Trinidad and Tobago": "North America",
"Bahrain": "Asia",
"Iceland": "Europe",
"Belarus": "Europe",
"Jamaica": "North America"
}

final['user_continent'] = final['user_country'].map(continent)

# %%
# map occupations
oc = {
'Student': 'Student',
'Engineer': 'Engineering professional',
'Civil Engineer': 'Engineering professional',
'student': 'Student',
'Lawyer': 'Legal professional',
'Software Engineer': 'Engineering professional',
'Photographer, Graphic Designer': 'Culture, media and sports',
'Consultant': 'Corporate managers and directors',
'Murders & Executions': '',
'Accountant, translator': 'Business professional',
'Director': 'Corporate managers and directors',
'Doc': 'Teaching and educational professional',
'F1pilot': 'Culture, media and sports',
'-Making Power Moves-': '',
'Attorney': 'Legal professional',
'IT Tech': 'IT professional',
'Air Traffic Controller': 'Technicians and associate professional',
'Broke ass college graduate': 'Student',
'Retired': 'Retired',
'Student (Accounting Major)': 'Student',
'Co-owner NASPAQ': 'Corporate managers and directors',
'Half arsed project engineer': 'Engineering professional',
'SAP Business One': 'IT professional',
'Project Manager for Farting Competitions': 'Corporate managers and directors',
'high school': 'Student',
'broke student': 'Student',
'husband and dad and MD': 'Health professional',
'VW': '',
'Dentist': 'Health professional',
'Veterinarian': 'Health professional',
'Computers': 'IT professional',
'Editor': 'Culture, media and sports',
'Self employed': 'Self employed',
'Automotive Illustrator': 'Design professional',
'Analyst/Programmer': 'IT professional',
'HR Analyst': 'IT professional',
'Investment Banking': 'Finance professional',
'Account Manager': 'Corporate managers and directors',
'Banker': 'Finance professional',
'Pilot': 'Technicians and associate professional',
'Professional engineer, Grad student': 'Student',
'Art Director': 'Corporate managers and directors',
'you mean my future job = I DUNNO GOOD QUESTION THO': '',
'Volkswagen Parts Advisor': 'Automotive Business professional',
'General Surgeon': 'Health professional',
'CLOTHING BUSINESS': 'Business professional',
'Auto-Journalist': 'Culture, media and sports',
'My job?I´ll get back on this one when I find one..': '',
'Dreaming.': '',
'Athlete, Music video director, Coach': 'Culture, media and sports',
'AutoTrader': 'Automotive Business professional',
'Marketer.': 'Business professional',
'President & CEO': 'Corporate managers and directors',
'Sales': 'Sales and servie',
'Real Estate Development': 'Business professional',
'Real Estate Broker': 'Business professional',
'DP World': 'DP Business professional',
'none': '',
'Mechanical engineer': 'Engineering professional',
'IT': 'IT professional',
'Construction': 'Engineering professional',
'Wireless Toys': '',
'civil engineer - site manager position': 'Engineering professional',
'Video Game Producer': 'IT professional',
'Designer': 'Desgin professional',
'Academics': 'Teaching and educational professional',
'Photographer for Car Press Magazines': 'Culture, media and sports',
'Med Student': 'Student',
'Credit Risk Analyst': 'IT professional',
'senior in high school': 'Student',
'Gas Engineer &amp; Plumber': 'Engineering professional',
'farm labour and school.': 'Student',
'(Hopefully soon) Civil Engineer': 'Engineering professional',
'Occu.. what?': '',
'Education Management': 'Teaching and educational professional',
'BeachBum': 'Culture, media and sports',
'I open doors!': '',
'Entrepreneur': 'Corporate managers and directors',
'Energy Trader': 'Business professional',
'Serial Entrepeneur, Restauranteur': '',
'Full-time student, occasional substitute teacher &': 'Student',
'Graphic designer': 'Design professional',
'SVP Operations': 'Corporate managers and directors',
'Technical Architect': 'Technicians and associate professional',
'Trucking Insurance Underwriter': 'Business professional',
'Aviator': '',
'Businessman': 'Business professional',
'Salesman': 'Sales and servie',
'Trainee barrister': 'Sales and servie',
'Sales Director': 'Sales and servie',
'student of social science': 'Student',
'P.F. Changs': '',
'Mar-Com': '',
'Software engineer - developing soft for VW &amp; A': 'Engineering professional',
'Retired in 1987': 'Retired',
"don't know yet :)": '',
'ADCO': 'Business professional',
'Jobs are over rated.': '',
'business': 'Business professional',
'Enterpreneur': 'Corporate managers and directors',
'Designer, entrepeneur.': 'Desgin professional',
'Pediatrician': 'Health professional',
'Self Employed': 'Self Employed',
'loving lambos': '',
'Porsche Sales': 'Sales and servie',
'Computer Technical': 'IT professional',
'Medical': 'Health professional',
'customer service representative': 'Sales and servie',
'School': 'Student',
'Spending Money': '',
'Sales &amp; Marketing Manager...ish': 'Corporate managers and directors',
'still school': 'Student',
'CIVIL ENGINEER': 'Engineering professional',
'database administrator': 'IT professional',
'Graphic Artist': 'Culture, media and sports',
'U.S. Navy': 'Army',
'Retired US Army': 'Army',
'project manager engineering': 'Engineering professional',
'Owner': 'Business professional',
'rust repair': 'Technicians and associate professional',
'Sales Consultant': 'Sales and servie',
'Physician': 'Health professional',
'Publisher': 'Culture, media and sports',
'Executive/Ceo': 'Corporate managers and directors',
'Professional Wheel Alignment Services - Tires': 'Sales and servie',
'OTR driver': 'Elementary occupations',
"N'ere do well": '',
'Marketing Rep': 'Business professional',
'Financial Analyst': 'IT professional',
'Plant Manager': 'Corporate managers and directors',
'Senior Aquatic Scientist': 'Scientist',
'High School Student/ Robo mechanical engineering i': '',
'accountant': 'Business professional',
'Loan Officer': 'Finance professional',
'Student (University)': 'Student',
'Graduate Student': 'Student',
'MD, Drivers Republic': '',
"Gov't Writer": 'Culture, media and sports',
'Bar Manager/ Amiture Photographer': 'Culture, media and sports',
'U.S.A.F. Tactical Aircraft Maintenance Technician': 'Army',
'Mecanical Engineering Student': 'Student',
'Student-mech eng': 'Student',
'Żary': '',
'GM': 'Automotive Business professional',
'Who REALLY knows what they do. Right? Am I right?': '',
'Auto Salvage Inspector': 'Automotive Business professional',
'Mechanical': 'Technicians and associate professional',
'Local Audi Showroom': 'Automotive Business professional',
'TELEVISION PRODUCTION': 'Culture, media and sports',
'software developer': 'IT professional',
'IT Professional': 'IT professional',
'Automotive Photographer': 'Culture, media and sports',
'Horticulturalist, Landscape Designer, CAD operator': 'Culture, media and sports',
'medical student': 'Student',
'Musican': 'Culture, media and sports',
'Network Engineer': 'Engineering professional',
'Royal Air Force': 'Army',
'Racer': 'Technicians and associate professional',
'Car Transporter': 'Elementary occupations',
'Engineer-in-training': 'Engineering professional',
"Renault's #1 competitor": '',
'computer science': 'Student',
'civil engineer': 'Engineering professional',
'Pff... Please.': '',
'Real Estate, Photographer': 'Culture, media and sports',
'Watching the grass grow in my garden': '',
'Binman': 'Elementary occupations',
'Chief Business Analyst': 'IT professional',
'translation agency, director': 'Corporate managers and directors',
'Accountant': 'Business professional',
'Substitute Teacher': 'Teaching and educational professional',
'Government drone': 'public service professional',
"Women's Fashion Footwear Designer": 'Design professional',
'Certified Personal Trainer': 'Sales and servie',
'Bank Manager': 'Finance professional',
'Content Writer': 'Culture, media and sports',
'Manager': 'Corporate managers and directors',
'Kfm. f. KEP / Qualitätsmanager': 'Corporate managers and directors',
'Analyst': 'IT professional',
'Finance Manager': 'Finance professional',
'Investments': 'Business professional',
'Quality Manager': 'Corporate managers and directors',
'Animation Director': 'Design professional',
'part time job at bmw washing cars': 'Elementary occupations',
'Suzuki Car Franchise Owner': 'Business professional',
'Independent Motor Vehicle Technician (retired)': 'Technicians and associate professional',
'sales': 'Sales and servie',
'Mercedes': 'Automotive business professional',
'Mechanical Engineer': 'Engineering professional',
'Insurance Underwritter': 'Business professional',
'Graphic Designer': 'Design professional',
'Legal Services': 'Legal professional',
'Corporate/Legal': 'Legal professional',
'Gas Fireplace Installer': 'Technicians and associate professional',
'Business Dev Manager Automotive Engineering': 'Automotive business professional',
'AMGs and cars': 'Automotive business professional',
}

final['occupation_group'] = final['user_occupation'].map(oc)

# %%
# user_birthday to datetime
final['user_birthday'] = final['user_birthday'].str.replace(r'\s+\(Age:\s+\d+\)$', '', regex=True)
date_pattern = r'(\w{3} [0-9]{1,2}, \d{4})'
final['user_birthday'] = final['user_birthday'].str.extract(date_pattern)
final['user_birthday'] = pd.to_datetime(final['user_birthday'], format='%b %d, %Y')
final.loc[final['user_birthday'].dt.year < 1907, 'user_birthday'] = ''
now = pd.Timestamp('now')
final["user_age"] = (now.year - final['user_birthday'].dt.year) - ((now.month - final['user_birthday'].dt.month) < 0)

# %%
# post_date to datetime
final['post_date'] = final['post_date'].str.split(' at').str[0]

final['post_date'] = final['post_date'].str.replace("Yesterday", "Jun 15, 2023")
final['post_date'] = final['post_date'].str.replace("Wednesday", "Jun 14, 2023")
final['post_date'] = final['post_date'].str.replace("Tuesday", "Jun 13, 2023")
final['post_date'] = final['post_date'].str.replace("Thursday", "Jun 8, 2023")
final['post_date'] = final['post_date'].str.replace("Monday", "Jun 12, 2023")
final['post_date'] = final['post_date'].str.replace("Today", "May 21, 2023")
final['post_date'] = final['post_date'].str.replace("Sunday", "May 14, 2023")
final['post_date'] = final['post_date'].str.replace("Saturday", "May 13, 2023")

final['post_date'] = pd.to_datetime(final['post_date'], format="%b %d, %Y")

# %%
# remove nonsense data in post_text
final['post_text'] = final['post_text'].str.replace("['__  ", "")
final['post_text'] = final['post_text'].str.replace("['- ", "")
final['post_text'] = final['post_text'].str.replace("-->>", "")
final['post_text'] = final['post_text'].str.replace("['-', '-', '!', '[image no longer available]']", "")
final['post_text'] = final['post_text'].str.replace("['-', '-']", "")
final['post_text'] = final['post_text'].str.replace("-', ", "")
final['post_text'] = final['post_text'].str.replace("[]", "")
final['post_text'] = final['post_text'].str.replace("['-']", "")
final['post_text'] = final['post_text'].str.replace("-->", "")
final['post_text'] = final['post_text'].str.replace("----", "")
final['post_text'] = final['post_text'].str.replace("---", "")
final['post_text'] = final['post_text'].str.replace("----->>", "")
final['post_text'] = final['post_text'].str.replace("['______________', ", "")
final['post_text'] = final['post_text'].str.replace("['__________________', '", "")
final['post_text'] = final['post_text'].str.replace("['_________________________', '", "")
final['post_text'] = final['post_text'].str.replace("--------------------------", "")
final['post_text'] = final['post_text'].str.replace("['______________________________', '______________________________', ", "")
final['post_text'] = final['post_text'].str.replace('["', "")
final['post_text'] = final['post_text'].str.replace('"]', "")
final['post_text'] = final['post_text'].str.replace("['", "")
final['post_text'] = final['post_text'].str.replace("']", "")
final['post_text'] = final['post_text'].str.replace("[video no longer available]", "")
final['post_text'] = final['post_text'].str.replace("'[video no longer available]',", "")
final['post_text'] = final['post_text'].str.replace("'[image no longer available]',", "")
final['post_text'] = final['post_text'].str.replace("[image no longer available]", "")

# %%
# clean replier_post_ID
final['replier_post_ID'] = final['replier_post_ID'].str.replace(",,,,,,,", "")
final['replier_post_ID'] = final['replier_post_ID'].str.replace(",,", "")
final['replier_post_ID'] = final['replier_post_ID'].str.replace("['', '']", "")
final['replier_post_ID'] = final['replier_post_ID'].str.replace("['", "")
final['replier_post_ID'] = final['replier_post_ID'].str.replace("']", "")
final['replier_post_ID'] = final['replier_post_ID'].str.replace("[", "")
final['replier_post_ID'] = final['replier_post_ID'].str.replace("]", "")
final['replier_post_ID'] = final['replier_post_ID'].str.replace("post: 0", "")
final['replier_post_ID'] = final['replier_post_ID'].str.replace("post: ", "")

# final.loc[2129, 'replier_post_ID'] = final.loc[2129, 'replier_post_ID'].replace(',', "")

# %% [markdown]
# ### Export csv

# %%
# final.to_csv("cleaned_NLP_final_v2_.csv")

# %% [markdown]
# -----

# %% [markdown]
# ## 1.3 Network analysis data

# %%
# split replier_post_ID
df1 = final.copy()

split_data = df1['replier_post_ID'].str.split(',', expand=False).fillna('')
max_elements = max([len(row) for row in split_data])
new_columns = [f'replier_post_ID_{i+1}' for i in range(max_elements)]
df1[new_columns] = pd.DataFrame([row[:max_elements] for row in split_data], index=df1.index)
df1[new_columns] = df1[new_columns].apply(lambda x: x.str.strip())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 7
#       5 max_elements = max([len(row) for row in split_data])
#       6 new_columns = [f'replier_post_ID_{i+1}' for i in range(max_elements)]
# ----> 7 df1[new_columns] = pd.DataFrame([row[:max_elements] for row in split_data], index=df1.index)
#       8 df1[new_columns] = df1[new_columns].apply(lambda x: x.str.strip())
#
# File /opt/anaconda3/envs/DL/lib/python3.11/site-packages/pandas/core/frame.py:3948, in DataFrame.__setitem__(self, key, value)
#    3946     self._setitem_frame(key, value)
#    3947 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3948     self._setitem_array(key, value)
#    3949 elif isinstance(value, DataFrame):
#    3950     self._set_item_frame_value(key, value)
#
# ...

# %%
# df1.to_csv("network_final_v1_.csv")

# %% [markdown]
# ## 1.4. User analysis data (drop duplicate users)

# %%
# for user analysis data
# user_analysis = df.copy()
# user_analysis  = user_analysis .drop_duplicates(subset=['post_username'], keep='last')

# %%
# user_analysis.to_csv("cleaned_user_analysis_v1.csv")
